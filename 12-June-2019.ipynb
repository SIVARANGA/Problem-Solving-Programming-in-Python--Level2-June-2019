# %% [markdown]
# # Problem Solving and programming
# ## Day Objective:
# - String Slicing
# - Function in Python
# - Basic Problems related to conditional statements using functions
# - Python data Structures - Lists , Tuples and Dictionaries
# - Basics operations on data structures
# - Apply Data structures to solve problems

# %% [markdown]
# ## String Slicing

# %%
string="Hii this ranga"

string
# Out:
# 'Hii this ranga'

# %%
string[1]
len(string)
string[-1]
string[10]
string[0:5]
string[-1:-10:-1]
string[-1: :-1]
string[ :3]
string[4: ]
string
string[1:-1]
string[1:len(string)-1]
string[len(string)//2]
string[int(len(string)//2)] #Accessing middle charactor
# Out:
# 's'
