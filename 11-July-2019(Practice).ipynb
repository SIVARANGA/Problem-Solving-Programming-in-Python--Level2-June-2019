# %%
n1=n2=n3=n4=123

# %%
n1
# Out:
# 123

# %%
n3
# Out:
# 123

# %%
n4
# Out:
# 123

# %%
n1,n2=34,67

# %%
n2
# Out:
# 67

# %%
k='''jwhdgjhdg
jdghwhj
jhdgj'''

# %%
fi=open("raga.txt",'a')
#fi.write('\n')
fi.write("who are you")
fi.close()

# %%
n=int(input())
e=open('raga.txt','a')
for i in range(1,n+1):
    if(i%2==0):
        e.write('\n'+str(i))
e.close()
# Out:
# 1000

# %%
filepath='Images/sine.png'

# %%
img=open(filepath,'rb')
data=img.read()

# %%
imc=open('ranga.jpg','wb')
imc.write(data)
imc.close()

# %%
import re

#Check if the string starts with "The" and ends with "Spain":

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if (x):
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %%
import re

#Check if the string starts with "The" and ends with "Spain":

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if (x):
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!
