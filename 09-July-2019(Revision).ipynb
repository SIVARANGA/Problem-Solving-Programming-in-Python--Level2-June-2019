# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
s="python"

s.capitalize()
# Out:
# 'Python'

# %%
p="siva ranga nayakulu"

f=p.split()

for i in f:
    op=i.capitalize()
    print(op,end=" ")
# Out:
# Siva Ranga Nayakulu

# %%
p

for i in p:
    k=i.capitalize()
    print(k,end="")
# Out:
# SIVA RANGA NAYAKULU

# %%
p.casefold()
# Out:
# 'siva ranga nayakulu'

# %%
f="RaNGanaYaKUlU"
f.casefold()
# Out:
# 'ranganayakulu'

# %%
l='SIVA RANGA NAYAKULU'
l.casefold()
# Out:
# 'siva ranga nayakulu'

# %%
s="Ranga"
s.center(20,'*')
# Out:
# '*******Ranga********'

# %%
p
# Out:
# 'siva ranga nayakulu'

# %%
p.count(" ")
# Out:
# 2

# %%
s.count('a')
# Out:
# 2

# %%
p.count('a')
# Out:
# 5

# %%
j=p.encode()
j
# Out:
# b'siva ranga nayakulu'

# %%
j.decode()
# Out:
# 'siva ranga nayakulu'

# %%
s
# Out:
# 'Ranga'

# %%
s1=s.encode()

s1
# Out:
# b'Ranga'

# %%
s1[0]
# Out:
# 82

# %%
ord('R')
# Out:
# 82

# %%
chr(82)
# Out:
# 'R'

# %%
s2=s1.decode()

s2
type(s2)
# Out:
# str

# %%
s2[0]
# Out:
# 'R'

# %%
s="ranganayakulu"
table=s.maketrans('abc','dwf',"gji")

table
# Out:
# {97: 100, 98: 119, 99: 102, 103: None, 106: None, 105: None}

# %%
s1
# Out:
# b'Ranga'

# %%
s1="anbjsbj"

s1.translate(table)
# Out:
# 'dnwsw'

# %%
name="ranguu sivaeee"

k=name.maketrans('ue','aa')

name.translate(k)
# Out:
# 'rangaa sivaaaa'

# %%
s="craete"

j=s.maketrans('','','a')

k=s.translate(j)

k.join()
# Out:
# 'crete'

# %%
s="craete"

d=s.split('e')
# Out:
# ['cra', 't', '']

# %%
help(str.maketrans)
# Out:
# Help on built-in function maketrans:
#
# maketrans(x, y=None, z=None, /)
#     Return a translation table usable for str.translate().
#
#     If there is only one argument, it must be a dictionary mapping Unicode
#     ordinals (integers) or characters to Unicode ordinals, strings or None.
#     Character keys will be then converted to ordinals.
#     If there are two arguments, they must be strings of equal length, and
#     in the resulting dictionary, each character in x will be mapped to the
#     character at the same position in y. If there is a third argument, it
#     must be a string, whose characters will be mapped to None in the result.

# %%
name1="first number ranga"

k=name1.split()
summa=""
for i in range(1,len(k)):
    #h=k[i].capitalize()
    summa+=k[i].capitalize()
    
print(k[0]+summa,end="")
# Out:
# firstNumberRanga

# %%
name="first name"

name.replace(" ","_")
# Out:
# 'first_name'

# %%
dict={"ranga":100,"shiva":200,"Alekhya":150,"gd":120,"rangu":60,"ramu":98}

k=set(sorted(dict.values(),reverse=True))

dict1={}
list1=[]

for i in range(0,len(k)):
    for j in dict.items():
        if k[i]==j[1]:
            dict1[i+1]=j[0]
            
dict1
# Out:
# {60, 98, 100, 120, 150, 200}

# %%
# Common Factors count in two numbers

n1=int(input())
n2=int(input())

k=max(n1,n2)
count=0
for i in range(1,k):
    if n1%i==0 and n2%i==0:
        count+=1
print(count)
# Out:
# 10
# 100
# 4

# %%
dict={"ranga":100,"shiva":200,"Alekhya":150,"gd":120,"rangu":60,"ramu":98}

k=set((dict.values()))

l=sorted(k,reverse=True)

dict1={}
list1=[]

for i in range(0,len(l)):
    for j in dict.items():
        if l[i]==j[1]:
            dict1[i+1]=j[0]
            
for h in dict1.items():
    print(h[0],h[1])
# Out:
# 1 shiva
# 2 Alekhya
# 3 gd
# 4 ranga
# 5 ramu
# 6 rangu

# %%
dict={"ranga":100,"shiva":200,"Alekhya":150,"gd":120,"rangu":60,"ramu":98}

k=set((dict.values()))

k=sorted(k,reverse=True)
k
# Out:
# [200, 150, 120, 100, 98, 60]

# %%
def coonvert(s):
    for i in s:
        if i.islower():
            i=i.upper()
            print(i,end="")
        elif i.isupper():
            i=i.lower()
            print(i,end="")
        
        
coonvert("AbcD")
# Out:
# aBCd

# %%
def isArmStrongNumber(num):
    len=
