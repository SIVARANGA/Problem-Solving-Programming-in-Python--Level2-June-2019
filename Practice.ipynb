# %%
num=int(input())
k=list(map(int,input().split()))
ans=1

a=1
for i in k:
    a=((ans*i)*a)
s=a%(10**9+7)
print(s)

# %%
2%(10**9+7)

# %%
def CountDivisors(low,high,div):
    count=0
    for i in range(low,high+1):
        if i%div==0:
            count=count+1
    print(count)
k=list(map(int,input().split()))
a=k[0]
b=k[1]
c=k[2]
CountDivisors(a,b,c)
# Out:
# 1 10 1
# 10

# %%
f=True
while():
    n=int(input())
    if n==42:
        break
    else:
        print(n)
# Out:
# 1
# 1
# 2
# 2
# 4
# 4
# 42

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    print(fact)
        
        
n=int(input())
factorial(n)
# Out:
# 5
# 120

# %%
def ConvertCharactors(s):
    for i in s:
        if i.isupper():
            k=i.lower()
            print(k,end="")
        elif i.islower():
            f=i.upper()
            print(f,end="")
    
    
s=input()
ConvertCharactors(s)
# Out:
# ALEkhya
# aleKHYA

# %%
n=int(input())
for i in range(n):
    string=input()
    h=list(string.split())
    if 
    
    
def check
# Out:
# 2
# siva avisa
# ['siva', 'avisa']
# ranga rangu
# ['ranga', 'rangu']

# %%
from itertools import permutations 
str="Alekhya"
permList = permutations(str) 

p=list(permList)
"".
# Out:
# [('A', 'l', 'e', 'k', 'h', 'y', 'a'), ('A', 'l', 'e', 'k', 'h', 'a', 'y'), ('A', 'l', 'e', 'k', 'y', 'h', 'a'), ('A', 'l', 'e', 'k', 'y', 'a', 'h'), ('A', 'l', 'e', 'k', 'a', 'h', 'y'), ('A', 'l', 'e', 'k', 'a', 'y', 'h'), ('A', 'l', 'e', 'h', 'k', 'y', 'a'), ('A', 'l', 'e', 'h', 'k', 'a', 'y'), ('A', 'l', 'e', 'h', 'y', 'k', 'a'), ('A', 'l', 'e', 'h', 'y', 'a', 'k'), ('A', 'l', 'e', 'h', 'a', 'k', 'y'), ('A', 'l', 'e', 'h', 'a', 'y', 'k'), ('A', 'l', 'e', 'y', 'k', 'h', 'a'), ('A', 'l', 'e', 'y', 'k', 'a', 'h'), ('A', 'l', 'e', 'y', 'h', 'k', 'a'), ('A', 'l', 'e', 'y', 'h', 'a', 'k'), ('A', 'l', 'e', 'y', 'a', 'k', 'h'), ('A', 'l', 'e', 'y', 'a', 'h', 'k'), ('A', 'l', 'e', 'a', 'k', 'h', 'y'), ('A', 'l', 'e', 'a', 'k', 'y', 'h'), ('A', 'l', 'e', 'a', 'h', 'k', 'y'), ('A', 'l', 'e', 'a', 'h', 'y', 'k'), ('A', 'l', 'e', 'a', 'y', 'k', 'h'), ('A', 'l', 'e', 'a', 'y', 'h', 'k'), ('A', 'l', 'k', 'e', 'h', 'y', 'a'), ('A', 'l', 'k', 'e', 'h', 'a', 'y'), ('A', 'l', 'k', 'e', 'y', 'h', 'a'), ('A', 'l', 'k', 'e', 'y', 'a', 'h'), ('A', 'l', 'k', 'e', 'a', 'h', 'y'), ('A', 'l', 'k', 'e', 'a', 'y', 'h'), ('A', 'l', 'k', 'h', 'e', 'y', 'a'), ('A', 'l', 'k', 'h', 'e', 'a', 'y'), ('A', 'l', 'k', 'h', 'y', 'e', 'a'), ('A', 'l', 'k', 'h', 'y', 'a', 'e'), ('A', 'l', 'k', 'h', 'a', 'e', 'y'), ('A', 'l', 'k', 'h', 'a', 'y', 'e'), ('A', 'l', 'k', 'y', 'e', 'h', 'a'), ('A', 'l', 'k', 'y', 'e', 'a', 'h'), ('A', 'l', 'k', 'y', 'h', 'e', 'a'), ('A', 'l', 'k', 'y', 'h', 'a', 'e'), ('A', 'l', 'k', 'y', 'a', 'e', 'h'), ('A', 'l', 'k', 'y', 'a', 'h', 'e'), ('A', 'l', 'k', 'a', 'e', 'h', 'y'), ('A', 'l', 'k', 'a', 'e', 'y', 'h'), ('A', 'l', 'k', 'a', 'h', 'e', 'y'), ('A', 'l', 'k', 'a', 'h', 'y', 'e'), ('A', 'l', 'k', 'a', 'y', 'e', 'h'), ('A', 'l', 'k', 'a', 'y', 'h', 'e'), ('A', 'l', 'h', 'e', 'k', 'y', 'a'), ('A', 'l', 'h', 'e', 'k', 'a', 'y'), ('A', 'l', 'h', 'e', 'y', 'k', 'a'), ('A', 'l', 'h', 'e', 'y', 'a', 'k'), ('A', 'l', 'h', 'e', 'a', 'k', 'y'), ('A', 'l', 'h', 'e', 'a', 'y', 'k'), ('A', 'l', 'h', 'k', 'e', 'y', 'a'), ('A', 'l', 'h', 'k', 'e', 'a', 'y'), ('A', 'l', 'h', 'k', 'y', 'e', 'a'), ('A', 'l', 'h', 'k', 'y', 'a', 'e'), ('A', 'l', 'h', 'k', 'a', 'e', 'y'), ('A', 'l', 'h', 'k', 'a', 'y', 'e'), ('A', 'l', 'h', 'y', 'e', 'k', 'a'), ('A', 'l', 'h', 'y', 'e', 'a', 'k'), ('A', 'l', 'h', 'y', 'k', 'e', 'a'), ('A', 'l', 'h', 'y', 'k', 'a', 'e'), ('A', 'l', 'h', 'y', 'a', 'e', 'k'), ('A', 'l', 'h', 'y', 'a', 'k', 'e'), ('A', 'l', 'h', 'a', 'e', 'k', 'y'), ('A', 'l', 'h', 'a', 'e', 'y', 'k'), ('A', 'l', 'h', 'a', 'k', 'e', 'y'), ('A', 'l', 'h', 'a', 'k', 'y', 'e'), ('A', 'l', 'h', 'a', 'y', 'e', 'k'), ('A', 'l', 'h', 'a', 'y', 'k', 'e'), ('A', 'l', 'y', 'e', 'k', 'h', 'a'), ('A', 'l', 'y', 'e', 'k', 'a', 'h'), ('A', 'l', 'y', 'e', 'h', 'k', 'a'), ('A', 'l', 'y', 'e', 'h', 'a', 'k'), ('A', 'l', 'y', 'e', 'a', 'k', 'h'), ('A', 'l', 'y', 'e', 'a', 'h', 'k'), ('A', 'l', 'y', 'k', 'e', 'h', 'a'), ('A', 'l', 'y', 'k', 'e', 'a', 'h'), ('A', 'l', 'y', 'k', 'h', 'e', 'a'), ('A', 'l', 'y', 'k', 'h', 'a', 'e'), ('A', 'l', 'y', 'k', 'a', 'e', 'h'), ('A', 'l', 'y', 'k', 'a', 'h', 'e'), ('A', 'l', 'y', 'h', 'e', 'k', 'a'), ('A', 'l', 'y', 'h', 'e', 'a', 'k'), ('A', 'l', 'y', 'h', 'k', 'e', 'a'), ('A', 'l', 'y', 'h', 'k', 'a', 'e'), ('A', 'l', 'y', 'h', 'a', 'e', 'k'), ('A', 'l', 'y', 'h', 'a', 'k', 'e'), ('A', 'l', 'y', 'a', 'e', 'k', 'h'), ('A', 'l', 'y', 'a', 'e', 'h', 'k'), ('A', 'l', 'y', 'a', 'k', 'e', 'h'), ('A', 'l', 'y', 'a', 'k', 'h', 'e'), ('A', 'l', 'y', 'a', 'h', 'e', 'k'), ('A', 'l', 'y', 'a', 'h', 'k', 'e'), ('A', 'l', 'a', 'e', 'k', 'h', 'y'), ('A', 'l', 'a', 'e', 'k', 'y', 'h'), ('A', 'l', 'a', 'e', 'h', 'k', 'y'), ('A', 'l', 'a', 'e', 'h', 'y', 'k'), ('A', 'l', 'a', 'e', 'y', 'k', 'h'), ('A', 'l', 'a', 'e', 'y', 'h', 'k'), ('A', 'l', 'a', 'k', 'e', 'h', 'y'), ('A', 'l', 'a', 'k', 'e', 'y', 'h'), ('A', 'l', 'a', 'k', 'h', 'e', 'y'), ('A', 'l', 'a', 'k', 'h', 'y', 'e'), ('A', 'l', 'a', 'k', 'y', 'e', 'h'), ('A', 'l', 'a', 'k', 'y', 'h', 'e'), ('A ...

# %%
n=int(input())
elements=list(map(int,input().split()))
list1={}
for i in elements:
    if i  in list1:
        list1[i]+=1
    else:
        list1[i]=1
        
p=int(input())
for j in range(p):
    c=int(input())
    print("c is ",c)
    print(list1[c])
    if c in list1.items():
        print(list1[c])
    elif c not in list1.items():
        
        print("NOT")"

# %%
def memorise():
   d={}
   for element in a:
       if element in d:
           d[element]+=1
       else:
           d[element]=1
   
   
   for i in (d.items()):
       print(d.items())
       if i[0]==di:
           print (i[1],"I VALUE")
       else:
           print("NOT PRESENT")
  
n=int(input())
a=list(map(int,input().split()))
q=int(input())
for i in range(q):
   di=int(input())
   memorise()
