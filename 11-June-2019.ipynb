# %% [markdown]
# ### Notebook Basics
#
# * **Bold**
# * *Itallic*
# * ***IB***
# * Normal Text
#     * jhj
#     * ranaf
#
#
# >1. Ordered list element 1
# >2. ordered list element 2
#
#
# * gvhgvhghgb
#
#
# ![Gandhi statement](images.jpg)
#
# <img src="images.jpg" style="float:left">
#
# > This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet
#
# > This is the first level of quoting.
# >
# > This is nested blockquote.
# > Back to the first level.
#
#
# > >## This is a header.
# >
# > 1.   This is the first list item.
# > 2.   This is the second list item.
# >
# > Here's some example code:
# >
# >     return shell_exec("echo $input | $markdown_script");
#
# <ol>
# <li>Bird</li>
# <li>McHale</li>
# <li>Parish</li>
# </ol>

# %% [markdown]
# ### Python Basics
#
# #### Python Version 3.7
#
# 1. Scripting
# 2. objective oriented

# %%
# Python Comments


print("Good Afternoon Alekhya","!!!!!!!",end="-->")
print("Hello Python")

#print is command for displaying output
# Out:
# Good Afternoon Alekhya !!!!!!!-->Hello Python

# %% [markdown]
# ## **Assignment**

# %%
n1=1234567

n2=n3=n4=n1

a,b,c=23,445,54

print("a=",a,"b=",b,"c=",c)
# Out:
# a= 23 b= 445 c= 54

# %% [markdown]
# ### Arithematic Operations
# ### +,-,*,%,/,**

# %%
n1/10

f=n1**125

type(f)

len(str(f))

f
# Out:
# ...

# %% [markdown]
# ## Data Types
#
# - int
# - float
# - string
# - double

# %%
f1=367456789009876.378867856789045678909876543234567890
round(f1)
# Out:
# 367456789009876

# %% [markdown]
# # Conditional

# %%
if f1<10**6:
    print("True")
else:
    print("False")

# %%
num=int(input("Enter the number"))
if num%2==0:
    print("Even")
else:
    print("odd")
# Out:
# Enter the number46
# Even

# %%
n1=int(input("Enter the first number"))
n2=int(input("Enter the second number"))
n3=int(input("Enter the third number"))
if n1>n2 and n1>n3:
    print("n1 is gratest Number")
elif n2>n3:
    print("n2 is grea")
else:
    print("n3")

# %%
num=int(input("Enter the number"))
if num%10==0:
    print("num is divisible by 10")
else:
    print("num is not divisible by 10")

# %%
num=int(input("Enter the number"))
n1=int(input("Enter lower number"))
n2=int(input("Enter the upper value"))
if num>=n1 and num<=n2:
    print("Given number in range")
else:
    print("Given is not in range")
# Out:
# Enter the number23
# Enter lower number10
# Enter the upper value30
# Given number in range

# %%
num=int(input("Enter the number"))
string=input("Enter the string")
if str(num)==string:
    print("Number and string both are equal content")
else:
    print("not equal")

# %%
year=int(input("Enter the year"))
if year%400==0 or year%4==0 and year!=0:
    print("Given year is leap year")
else:
    print("not a leap year")
# Out:
# Enter the year2100
# Given year is leap year

# %%
num=int(input("Enter number"))
for i in range(1,num+1):
    if num%i==0:
        print(i)
# Out:
# Enter number1000
# 1
# 2
# 4
# 5
# 8
# 10
# 20
# 25
# 40
# 50
# 100
# 125
# 200
# 250
# 500
# 1000

# %%
num=int(input("Enter the number"))
if num%1000==0:
    print("given number is factor of number")
else:
    print("given number is not a factor of number")

# %%
num=int(input("Enter the number"))
op=(num)**0.5
op
# Out:
# Enter the number4
# 2.0

# %% [markdown]
# ## Conditionals Statements

# %%
f<10**67 and f>10**678
# Out:
# False
