# %%
li=input().split()
di={}
for i in li:
    if i in di:
        di[i]=1+d[i]
    else:
        di[i]=1
print(di)
# Out:
# d d d f g e s s
# {'d': 3, 'f': 1, 'g': 1, 'e': 1, 's': 2}
# <function dict.keys>

# %%
li1=input().split()
for i in li1:
    print(i)
    #print(j)
# Out:
# fr frf fr f r
# fr
# frf
# fr
# f
# r

# %%
l1=input().split(",")
di1={}
for i in set(l1):
    if l1.count(i) in di1:
        di1[l1.count(i)].append(i)
    else:
        di1[l1.count(i)]=[i]
        
di1
# Out:
# http://www.wikipedia.com ,https://www.google.co.in,https://www.hackerearth.com,https://www.hackerearth.com,https://www.hackerearth.com
# {1: ['http://www.wikipedia.com',
#   ',https://www.google.co.in,https://www.hackerearth.com,https://www.hackerearth.com,https://www.hackerearth.com']}

# %%
for k,j in di1.items():
    if len(j)==1:
        print(j[0])
    else:
        li=j[:]
        li.sort()
        for k in li:
            print(k)
# Out:
# ,https://www.google.co.in,https://www.hackerearth.com,https://www.hackerearth.com,https://www.hackerearth.com
# http://www.wikipedia.com

# %%
def SumUniqueNumbersThreedigits(li):
    li=set(li)
    add=0
    count=0
    for number in li:
        if len(str(number))==3:
            add=add+number
            count=count+1
    g=add//count
    print(g)
    
    
li=list(map(int,input().split()))
SumUniqueNumbersThreedigits(li)
# Out:
# 12 34 100 200 120
# 140

# %%
def findAbslouteDiffernce(li):
    lis=[]
    for i in range(len(li)-1):
        for j in range(i+1,len(li)):
            k=abs(li[i]-li[j])
            lis.append(k)
    print(min(lis))

n=int(input())
for count in range(n):
    h=list(map(int,input().split()))
    findAbslouteDiffernce(h)
# Out:
# 3
# 1 3 7 11
# 2
# 4 8 14 21
# 4
# 5 10 23
# 5

# %%
def combinations(li):
    g=[]
    for i in range(len(li)-1):
       #print(i,"ivalue")
       for j in range(i+1,len(li)):
            h=abs(li[i]-li[j])
            
           #print(j,"jvalue")
            
           print(li[i],li[j])
    return
li=[1,2,3,4,5]
combinations(li)
# Out:
# 1 2
# 1 3
# 1 4
# 1 5
# 2 3
# 2 4
# 2 5
# 3 4
# 3 5
# 4 5

# %%
def findRemainders(n):
    d1={}
    for i in range(1,n):
        d1[i]=n%i
    print(d1)
findRemainders(5)
values=d1.
for v
# Out:
# {1: 0, 2: 1, 3: 2, 4: 1}

# %%
h=[-1 2 4 -5 7]
