# %%
s={1,23,4,6,7}
s
# Out:
# {1, 4, 6, 7, 23}

# %%
s.add(8)
s
# Out:
# {1, 4, 6, 7, 8, 23}

# %%
s.remove(23)
s

# %%
s.clear()

# %%
s={1,3,5,7,9,12}
s.discard(7)
s
# Out:
# {1, 3, 5, 9, 12}

# %%
t=[1,2,3,4,5,6]
s.update(t)
s
# Out:
# {1, 2, 3, 4, 5, 6, 9, 12}

# %%
list=(4,9,10,3,4)
s.union(list)
s
# Out:
# {1, 2, 3, 4, 5, 6, 9, 12}

# %%
s.intersection_update(t)
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
k={1,2,3,4,5}
y=[6,7,8,9,10,1]
k.intersection_update(y)
k
# Out:
# {1}

# %%
k={1,2,3,4,5}
y={6,7,8,9,10,1}
k-y
# Out:
# {2, 3, 4, 5}

# %%
y-k
# Out:
# {6, 7, 8, 9, 10}

# %%
k^y
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 10}

# %%
d=k.intersection(y)
d
# Out:
# {1}

# %%
d=set()
d
# Out:
# set()

# %% [markdown]
# ### Functional Programming
